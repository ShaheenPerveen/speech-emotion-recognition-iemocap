# %%
import numpy as np
import pandas as pd
import os.path
import librosa
import IPython.display as ipd
from shutil import copyfile
import glob
import matplotlib.style as ms
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle
import random
import time

import IPython.display
import librosa.display
import joblib
from joblib import Parallel, delayed
from PIL import Image
import multiprocessing as mp

# %%
sr = 22050

# %%
import pandas as pd
import math

labels_df = pd.read_csv('/home/user/shaheen.perveen/SER_new/preprocess_info/df_iemocap.csv')
iemocap_dir = '/home/user/shaheen.perveen/SER_new/IEMOCAP_full_release/'
save_dir = '/home/user/shaheen.perveen/SER_new/preprocess_info/'
audio_vectors_path= save_dir + 'audio_vectors_'

# %%
labels_df.emotion.value_counts()
# Out:
# xxx    2507
# fru    1849
# neu    1708
# ang    1103
# sad    1084
# exc    1041
# hap     595
# sur     107
# fea      40
# oth       3
# dis       2
# Name: emotion, dtype: int64

# %%
emotion_dict = {'ang': 0,
                'hap': 1,
                'exc': 2,
                'sad': 3,
                'fru': 4,
                'fea': 5,
                'sur': 6,
                'neu': 7,
                'xxx': 8,
                'oth': 8,
                'dis': 8}

# %%
emotion_full_dict = {'neu': 'neutral', 'ang': 'anger', 'hap': 'happiness', 'exc': 'excited', 'sad': 'sadness',
                     'fru':'frustrated', 'fea': 'fear', 'sur': 'surprised', 'xxx': 'others', 'oth': 'others', 'dis': 'others'}

# %%
labels_df.shape
# Out:
# (10039, 7)

# %%
labels_df.head()
# Out:
#    start_time  end_time             wav_file emotion  val  act  dom
# 0      3.9500   10.5900  Ses01F_impro07_F000     exc  5.0  5.0  4.5
# 1     11.3600   16.5575  Ses01F_impro07_F001     xxx  4.0  4.5  3.5
# 2     19.6100   31.6500  Ses01F_impro07_F002     exc  4.0  4.0  3.0
# 3     32.5200   34.9000  Ses01F_impro07_F003     exc  4.5  4.5  4.5
# 4     37.1625   42.4900  Ses01F_impro07_F004     exc  3.0  3.5  3.0

# %%
labels_df[labels_df["wav_file"].str.contains("Ses01")].shape
# Out:
# (1819, 7)

# %%
labels_df[labels_df["wav_file"].str.contains("Ses02")].shape
# Out:
# (1811, 7)

# %%
labels_df[labels_df["wav_file"].str.contains("Ses03")].shape
# Out:
# (2136, 7)

# %%
labels_df[labels_df["wav_file"].str.contains("Ses04")].shape
# Out:
# (2103, 7)

# %%
labels_df[labels_df["wav_file"].str.contains("Ses05")].shape
# Out:
# (2170, 7)

# %%
labels_df_subset = labels_df[labels_df["emotion"].isin(["neu", 'ang', 'hap', 'sad'])]

# %%
labels_df_subset.emotion.value_counts()
# Out:
# neu    1708
# ang    1103
# sad    1084
# hap     595
# Name: emotion, dtype: int64

# %%
labels_df_subset = labels_df_subset[["wav_file", "emotion"]]

# %%
labels_df_subset = labels_df_subset.rename(columns={"wav_file": "filename"})

# %%
labels_df_subset.head()
# Out:
#                filename emotion
# 29  Ses01F_impro07_M012     neu
# 30  Ses01F_impro07_M013     neu
# 35  Ses01F_impro07_M018     neu
# 36  Ses01F_impro07_M019     hap
# 37  Ses01F_impro03_F000     hap

# %%
pickle_to_df = pd.DataFrame(columns=["filename", "audio_vector"])

# %%
for sess in range(1, 6):
    audio_vectors = pickle.load(open('{}{}.pkl'.format(audio_vectors_path, sess), 'rb'))
    for index, row in tqdm(labels_df[labels_df['wav_file'].str.contains('Ses0{}'.format(sess))].iterrows()):

        wav_file_name = row['wav_file']
        y = audio_vectors[wav_file_name]
        list_y = list(y)
        pickle_to_df = pickle_to_df.append({'filename': wav_file_name, 'audio_vector': list_y}, ignore_index=True)
# Out:
# 1819it [00:17, 102.52it/s]
# 1811it [00:15, 120.48it/s]
# 2136it [00:18, 113.19it/s]
# 2103it [00:18, 115.87it/s]
# 2170it [00:31, 68.59it/s]

# %%
pickle_to_df.to_csv('/home/user/shaheen.perveen/SER_new/preprocess_info/pickle_to_audiodf.csv')

# %%
pickle_to_df.shape
# Out:
# (10039, 2)

# %%
pickle_to_df.head()
# Out:
#               filename                                       audio_vector
# 0  Ses01F_impro07_F000  [-0.014475782, -0.019586077, -0.021079177, -0....
# 1  Ses01F_impro07_F001  [0.0028844632, -0.00027148638, -0.0038992136, ...
# 2  Ses01F_impro07_F002  [0.013327659, 0.009810394, 0.003759945, 0.0004...
# 3  Ses01F_impro07_F003  [0.0014638001, 0.003141048, 0.0072772643, 0.01...
# 4  Ses01F_impro07_F004  [-0.011886216, -0.012354498, -0.013181173, -0....

# %%
pickle_to_subset = labels_df_subset.merge(pickle_to_df, on="filename")

# %%
print(pickle_to_subset.shape)
print(pickle_to_df.shape)
print(labels_df_subset.shape)
# Out:
# (4490, 3)
# (10039, 2)
# (4490, 2)

# %%
pickle_to_subset.head()
# Out:
#               filename emotion  \
# 0  Ses01F_impro07_M012     neu
# 1  Ses01F_impro07_M013     neu
# 2  Ses01F_impro07_M018     neu
# 3  Ses01F_impro07_M019     hap
# 4  Ses01F_impro03_F000     hap
#
#                                         audio_vector
# 0  [-0.001751249, -0.0022995116, -0.0022942421, -...
# 1  [0.0003422114, 0.0027063466, 0.0076859626, 0.0...
# 2  [0.032214236, 0.035951234, 0.03672457, 0.03514...
# 3  [-0.08024377, -0.078011915, -0.084221944, -0.1...
# 4  [-0.002304704, -0.0011479069, -0.001996223, -0...

# %%
pathAudio = iemocap_dir
pathImage = '/home/user/shaheen.perveen/SER_new/IEMOCAP_Image/'

# %%
sr = 22050
start = time.time()
def save_spectrogram(y, image_fname, label):
    try:
        start1 = time.time()
        print("inside function")
        S = librosa.feature.melspectrogram(np.asarray(y), sr=sr, n_mels=128)
        log_S = librosa.power_to_db(S, ref=np.max)
        librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')
        fig1 = plt.gcf()
        plt.axis('off')
        plt.draw()
        save_path = pathImage + emotion_full_dict[label] + '/' + image_fname + '.jpg'
        fig1.savefig(save_path, dpi=50)
        end1 =  time.time()
        print(end1 - start1)
    except:
        print("no spectrogram was saved for file {}".format(image_fname))
    
pool = mp.Pool(mp.cpu_count())
pool_starmap = pool.starmap_async(save_spectrogram,[(getattr(row, "audio_vector"), getattr(row, "filename"), getattr(row, "emotion")) for row in pickle_to_subset.itertuples(index=True, name='Pandas')])
pool_starmap.wait()
pool.close()
end = time.time()
print(end-start)
# Out:
# inside function
# 0.09028887748718262
# inside function
# 0.06975269317626953
# inside function
# 0.12736749649047852
# inside function
# 0.21600031852722168
# inside function
# 0.18138718605041504
# inside function
# 0.34188389778137207
# inside function
# 0.2857949733734131
# inside function
# 0.3568308353424072
# inside function
# 0.30513739585876465
# inside function
# 0.3956298828125
# inside function
# 0.5662639141082764
# inside function
# 0.3938620090484619
# inside function
# 0.5605061054229736
# inside function
# 0.48540449142456055
# inside function
# 0.38217854499816895
# inside function
# 0.5092554092407227
# inside function
# 0.7459118366241455
# inside function
# 0.7003982067108154
# inside function
# 0.4636707305908203
# inside function
# 0.6400892734527588
# inside function
# 0.745598316192627
# inside function
# 0.632249116897583
# inside function
# 0.6281948089599609
# inside function
# 0.6689863204956055
# inside function
# 0.5606374740600586
# inside function
# 0.5693116188049316
# inside function
# 0.7742009162902832
# inside function
# 0.5943655967712402
# inside function
# 0.6655526161193848
# inside function
# inside function
# 0.2747623920440674
# inside function
# 0.29256176948547363
# inside function
# 0.9002711772918701
# inside function
# 0.15933442115783691
# inside function
# 0.22535061836242676
# inside function
# 0.7735939025878906
# inside function
# 1.314756155014038
# inside function
# 0.36604762077331543
# inside function
# 0.5658354759216309
# inside function
# 0.40146446228027344
# inside function
# 1.2903215885162354
# inside function
# 0.24672174453735352
# inside function
# 0.5981616973876953
# inside function
# 1.0498456954956055
# inside function
# 0.5418620109558105
# inside function
# 0.43498659133911133
# inside function
# 0.9815280437469482
# inside function
# 0.4136083126068115
# inside function
# 0.5560762882232666
# inside function
# 0.5128443241119385
# inside function
# 1.2572360038757324
# inside function
# 0.4070415496826172
# inside function
# 0.5572645664215088
# inside function
# 1.3861188888549805
# inside function
# 0.7183845043182373
# inside function
# 0.47360849380493164
# inside function
# 1.0172994136810303
# inside function
# 1.134397029876709
# inside function
# 1.5004830360412598
# inside function
# 0.7831170558929443
# inside function
# 1.5826706886291504
# inside function
# 0.594900369644165
# inside function
# 0.8763213157653809
# inside function
# 1.6070430278778076
# inside function
# 1.0091392993927002
# inside function
# 1.3115713596343994
# inside function
# 1.0104639530181885
# inside function
# 0.782752513885498
# inside function
# 1.6681489944458008
# inside function
# 1.0538034439086914
# inside function
# 1.240006923675537
# inside function
# 1.0487053394317627
# inside function
# 1.0336692333221436
# inside function
# 1.0852138996124268
# inside function
# 1.3857202529907227
# inside function
# 1.4428060054779053
# inside function
# 1.1038012504577637
# inside function
# 1.6084215641021729
# inside function
# 1.3460934162139893
# inside function
# 1.7206413745880127
# 0.7713479995727539
# inside function
# inside function
# 0.5058586597442627
# inside function
# 0.0758821964263916
# inside function
# 0.139786958694458
# inside function
# 0.17957162857055664
# inside function
# 0.1899256706237793
# inside function
# 1.4489657878875732
# inside function
# 0.1759040355682373
# inside function
# 0.337780237197876
# inside function
# 0.2732889652252197
# inside function
# 0.5278677940368652
# inside function
# 0.69140625
# inside function
# 2.0326809883117676
# inside function
# 1.017613410949707
# inside function
# 0.46529197692871094
# inside function
# 1.6226718425750732
# inside function
# 0.511235237121582
# inside function
# 1.4192299842834473
# inside function
# 2.2473630905151367
# inside function
# 1.0192172527313232
# inside function
# 1.5082216262817383
# inside function
# 1.1000745296478271
# inside function
# 1.2911958694458008
# inside function
# 2.2396883964538574
# inside function
# 1.440197229385376
# inside function
# 0.7292325496673584
# inside function
# 1.7608706951141357
# inside function
# 1.0032308101654053
# inside function
# 0.7877418994903564
# inside function
# 1.609938621520996
# inside function
# 1.332963466644287
# inside function
# 1.4755427837371826
# inside function
# 1.2487390041351318
# inside function
# 0.5994186401367188
# inside function
# 1.970771312713623
# inside function
# 1.4841523170471191
# inside function
# 1.370018482208252
# inside function
# 1.2886245250701904
# inside function
# 1.4826006889343262
# inside function
# 1.4900202751159668
# inside function
# 1.0325746536254883
# inside function
# 2.74606990814209
# inside function
# 1.4275851249694824
# 2.247603178024292
# inside function
# 1.0653598308563232
# inside function
# 1.1777939796447754
# inside function
# 1.0343623161315918
# inside function
# inside function
# 0.5364704132080078
# inside function
# 0.15734434127807617
# inside function
# 0.19143462181091309
# inside function
# 0.25472426414489746
# inside function
# 0.267547607421875
# inside function
# 2.6081786155700684
# inside function
# 0.29583096504211426
# inside function
# 1.4586598873138428
# inside function
# 1.0647823810577393
# inside function
# 0.777684211730957
# inside function
# 4.557744026184082
# inside function
# 1.563405990600586
# inside function
# 1.5293540954589844
# inside function
# 2.4613282680511475
# inside function
# 1.8548228740692139
# inside function
# 2.837754487991333
# inside function
# 1.4386532306671143
# inside function
# 2.5447490215301514
# inside function
# 2.3782830238342285
# inside function
# 1.9256322383880615
# inside function
# 3.7595174312591553
# inside function
# 1.8406727313995361
# inside function
# 2.411593198776245
# inside function
# 4.09944486618042
# inside function
# 2.2780628204345703
# inside function
# inside function
# 1.712310552597046
# inside function
# 1.034578561782837
# inside function
# 0.12723922729492188
# inside function
# 0.7866809368133545
# inside function
# 0.2537806034088135
# inside function
# 1.4226830005645752
# inside function
# 5.840904474258423
# 0.6256048679351807
# inside function
# inside function
# 0.34624671936035156
# inside function
# 0.6146266460418701
# inside function
# 3.260500907897949
# inside function
# 3.0027098655700684
# inside function
# 1.7810792922973633
# inside function
# 2.9608922004699707
# inside function
# 3.731544017791748
# inside function
# 14.998072862625122
# inside function
# 5.205327033996582
# inside function
# 4.376199722290039
# inside function
# 1.773435354232788
# inside function
# inside function
# 0.5844278335571289
# inside function
# 1.9969508647918701
# inside function
# 0.18684601783752441
# inside function
# 0.2542860507965088
# inside function
# 0.6610939502716064
# inside function
# 4.9904937744140625
# inside function
# 3.4864988327026367
# inside function
# 11.238707780838013
# inside function
# 1.477971076965332
# inside function
# 13.591490268707275
# inside function
# 6.310531377792358
# inside function
# 9.36859941482544
# inside function
# 10.258753538131714
# inside function
# 2.2187533378601074
# inside function
# 2.9287917613983154
# inside function
# 6.104785203933716
# inside function
# 14.801605701446533
# 10.679898977279663
# inside function
# inside function
# 3.439018964767456
# inside function
# 3.5698585510253906
# inside function
# inside function
# 7.380009651184082
# inside function
# 6.860605478286743
# inside function
# 8.266573429107666
# inside function
# 8.219387769699097
# inside function
# 3.4159555435180664
# inside function
# 5.2533416748046875
# inside function
# 18.744457006454468
# inside function
# 4.33653998374939
# inside function
# 6.587208271026611
# inside function
# 2.142103433609009
# inside function
# 7.847719669342041
# inside function
# 4.6516194343566895
# 1.0118038654327393
# inside function
# inside function
# 3.7121288776397705
# inside function
# 0.6280004978179932
# inside function
# 0.5845727920532227
# inside function
# 2.1973023414611816
# inside function
# 0.8424897193908691
# inside function
# inside function
# 23.918107509613037
# inside function
# 12.854507684707642
# inside function
# 9.654488325119019
# inside function
# 5.67696738243103
# inside function
# 13.987943887710571
# inside function
# 2.4248251914978027
# inside function
# 9.247488737106323
# inside function
# 11.160520076751709
# inside function
# 6.597738981246948
# inside function
# inside function
# 4.477818727493286
# inside function
# 14.943791627883911
# inside function
# 1.9557151794433594
# inside function
# 10.450276851654053
# inside function
# 26.094727039337158
# 29.769334316253662
# inside function
# 5.363507032394409
# inside function
# 2.439131498336792
# inside function
# 1.8133111000061035
# inside function
# 17.060536861419678
# inside function
# 5.013556003570557
# inside function
# 4.12337327003479
# inside function
# 5.862786769866943
# inside function
# 1.9178321361541748
# 0.4762904644012451
# inside function
# inside function
# inside function
# 0.7699296474456787
# inside function
# 39.50594162940979
# 1.628760814666748
# inside function
# 6.548114776611328
# inside function
# inside function
# 18.374881267547607
# 2.9312894344329834
# inside function
# inside function
# 5.534847736358643
# inside function
# 2.9499473571777344
# inside function
# 4.046565532684326
# inside function
# 6.822187185287476
# inside function
# 4.328205347061157
# inside function
# 6.184771299362183
# inside function
# 11.481168985366821
# inside function
# 2.3728506565093994
# inside function
# 4.0148491859436035
# inside function
# 0.6833715438842773
# inside function
# 11.389519691467285
# inside function
# 0.4742295742034912
# inside function
# 3.8094420433044434
# inside function
# 12.505537986755371
# inside function
# 10.2567458152771
# 1.8531417846679688
# inside function
# inside function
# inside function
# 38.59288811683655
# 10.159144878387451
# inside function
# inside function
# 6.853347063064575
# inside function
# 10.531318664550781
# inside function
# 3.0273935794830322
# inside function
# 14.256407499313354
# inside function
# 23.43435835838318
# inside function
# 14.824840307235718
# inside function
# 11.908838510513306
# inside function
# 7.964684963226318
# inside function
# 6.055376768112183
# inside function
# 7.554440975189209
# inside function
# 4.483527898788452
# inside function
# 1.6582551002502441
# inside function
# 3.373166799545288
# inside function
# 7.678813457489014
# inside function
# 7.527764558792114
# inside function
# 25.41026496887207
# inside function
# 18.688201427459717
# inside function
# 3.709851026535034
# inside function
# 52.88404893875122
# inside function
# inside function
# 5.683551788330078
# inside function
# 19.7639799118042
# inside function
# 2.7215728759765625
# inside function
# 9.575635433197021
# inside function
# 9.044569969177246
# inside function
# 1.9480643272399902
# inside function
# 16.060658931732178
# inside function
# 2.0693652629852295
# inside function
# 8.704352855682373
# inside function
# 18.028510808944702
# inside function
# inside function
# 7.380984783172607
# inside function
# 12.490452766418457
# inside function
# 2.4147865772247314
# inside function
# 2.010969877243042
# inside function
# 0.5317964553833008
# inside function
# 10.524401426315308
# inside function
# 9.805930852890015
# inside function
# 18.95130968093872
# inside function
# 13.886043787002563
# inside function
# 12.3126699924469
# 39.54507565498352
# inside function
# inside function
# 9.895445585250854
# inside function
# 9.144947052001953
# inside function
# 40.35978031158447
# inside function
# 8.681081295013428
# inside function
# 7.210186719894409
# inside function
# 8.144556760787964
# inside function
# 12.955767393112183
# inside function
# 33.4346079826355
# inside function
# 17.561831951141357
# inside function
# 52.600733280181885
# inside function
# 21.379464149475098
# inside function
# 11.016138553619385
# inside function
# inside function
# 16.864933252334595
# inside function
# 16.15510106086731
# 6.576623916625977
# inside function
# inside function
# 18.757233142852783
# inside function
# 10.394370079040527
# inside function
# 9.1356520652771
# inside function
# 1.5739107131958008
# inside function
# 19.821659803390503
# inside function
# 7.542806625366211
# inside function
# 8.016266584396362
# inside function
# 13.320800065994263
# inside function
# 17.738718509674072
# inside function
# 31.12420082092285
# 20.873467206954956
# inside function
# inside function
# 19.107316732406616
# 12.74414849281311
# inside function
# inside function
# 6.899812698364258
# inside function
# 31.196361541748047
# inside function
# 57.38538932800293
# inside function
# 5.300881624221802
# 43.692161321640015
# 16.832570791244507
# inside function
# inside function
# inside function
# 21.34238338470459
# inside function
# 16.418198347091675
# inside function
# 70.13528084754944
# inside function
# inside function
# 36.21359205245972
# inside function
# 2.8617939949035645
# inside function
# 12.084656000137329
# inside function
# 22.823435068130493
# inside function
# 18.143597841262817
# inside function
# 32.960440158843994
# inside function
# 37.31482458114624
# inside function
# 9.896661281585693
# inside function
# 17.160152912139893
# inside function
# 9.305837631225586
# inside function
# 25.877878189086914
# inside function
# 21.85535502433777
# inside function
# 4.670222043991089
# inside function
# inside function
# 14.349930763244629
# inside function
# 16.55216383934021
# 14.634150266647339
# inside function
# inside function
# 5.401975154876709
# inside function
# 17.211621284484863
# inside function
# 23.981971502304077
# 7.952880144119263
# inside function
# inside function
# 26.961008310317993
# 18.506689071655273
# inside function
# inside function
# inside function
# 53.886638879776
# inside function
# 12.414811849594116
# inside function
# 51.83038640022278
# inside function
# 9.928169012069702
# inside function
# 40.3075737953186
# inside function
# 10.749143123626709
# inside function
# 11.97730278968811
# inside function
# 8.449939250946045
# inside function
# 21.201005697250366
# inside function
# 28.829246282577515
# 47.30853271484375
# inside function
# 25.355031490325928
# 24.080613613128662
# inside function
# inside function
# inside function
# 8.510638952255249
# inside function
# inside function
# 7.96053409576416
# inside function
# 16.711158990859985
# inside function
# 18.54199457168579
# inside function
# 40.34292960166931
# 17.848047494888306
# inside function
# 10.361703872680664
# inside function
# 29.900808334350586
# inside function
# 39.9713978767395
# 12.874492645263672
# inside function
# inside function
# 17.07382321357727
# inside function
# 23.5316059589386
# inside function
# 89.17042064666748
# inside function
# 21.79415011405945
# inside function
# 10.91017460823059
# inside function
# inside function
# 22.28977680206299
# inside function
# 17.770182132720947
# inside function
# inside function
# 12.003118753433228
# inside function
# 18.13787007331848
# inside function
# 37.75449180603027
# inside function
# 32.64695596694946
# 33.42572855949402
# inside function
# inside function
# 29.838802814483643
# inside function
# 35.70598649978638
# inside function
# 24.08246111869812
# inside function
# 11.442619323730469
# inside function
# 13.618632793426514
# inside function
# 23.853572130203247
# inside function
# 26.247223377227783
# 16.182734727859497
# 32.342652559280396
# inside function
# 44.73592519760132
# inside function
# inside function
# 70.49065899848938
# inside function
# inside function
# 18.93722176551819
# inside function
# inside function
# inside function
# 9.086128234863281
# inside function
# 18.146065711975098
# inside function
# 9.416785717010498
# inside function
# 19.663248538970947
# inside function
# 4.00741720199585
# inside function
# 28.043718814849854
# inside function
# 64.8398208618164
# inside function
# 5.3531599044799805
# inside function
# 100.58879828453064
# inside function
# 45.18255066871643
# inside function
# 36.04497838020325
# 22.78639006614685
# 17.661039352416992
# inside function
# 9.72664999961853
# inside function
# 33.42530298233032
# inside function
# 2.3325958251953125
# inside function
# 52.64186501502991
# inside function
# 72.20570683479309
# inside function
# inside function
# inside function
# 35.316261291503906
# inside function
# inside function
# 7.567059755325317
# inside function
# 40.22600507736206
# inside function
# 14.1325101852417
# inside function
# 44.72863745689392
# 37.80702996253967
# inside function
# 48.88822889328003
# inside function
# 9.44581413269043
# inside function
# 17.746739387512207
# inside function
# inside function
# 11.764859199523926
# inside function
# inside function
# 15.517641544342041
# inside function
# 11.598198175430298
# inside function
# 38.46201467514038
# inside function
# 48.51465845108032
# inside function
# 35.04100728034973
# inside function
# 8.292687177658081
# inside function
# 5.953054666519165
# inside function
# 11.436261415481567
# inside function
# 22.30686902999878
# inside function
# 45.52467727661133
# 69.46601152420044
# 28.210817575454712
# 29.84696888923645
# 6.083601713180542
# inside function
# inside function
# 63.77462601661682
# inside function
# inside function
# inside function
# 55.49999284744263
# inside function
# 13.34384298324585
# 74.43478059768677
# inside function
# 9.060998916625977
# inside function
# inside function
# inside function
# 35.868098735809326
# 52.385520696640015
# inside function
# inside function
# inside function
# 12.624343633651733
# inside function
# 1.9664838314056396
# inside function
# 45.252259969711304
# 27.626145124435425
# inside function
# inside function
# 62.1688449382782
# inside function
# inside function
# inside function
# 31.44997549057007
# inside function
# 11.647418022155762
# inside function
# 18.816957712173462
# 20.487409591674805
# inside function
# 33.08633518218994
# 38.8463408946991
# inside function
# 40.363911867141724
# inside function
# 53.3893780708313
# inside function
# inside function
# 42.71110439300537
# inside function
# inside function
# 39.66956377029419
# inside function
# 6.925254821777344
# inside function
# 46.243064403533936
# inside function
# inside function
# inside function
# 13.851771354675293
# inside function
# 61.86370253562927
# 12.04786491394043
# inside function
# inside function
# 25.32192087173462
# inside function
# inside function
# 1.0274178981781006
# inside function
# 2.4785854816436768
# inside function
# inside function
# 60.770015001297
# 146.56391525268555
# inside function
# 49.461116552352905
# inside function
# inside function
# 17.87360906600952
# 13.354299545288086
# inside function
# inside function
# 38.92238736152649
# inside function
# 21.08619475364685
# 26.54017186164856
# 65.25513768196106
# inside function
# inside function
# inside function
# inside function
# inside function
# inside function
# 49.88569688796997
# 42.69594955444336
# 50.70658826828003
# inside function
# 23.920666694641113
# 25.13932466506958
# inside function
# 88.42679858207703
# 7.4497528076171875
# inside function
# inside function
# 27.17408514022827
# inside function
# inside function
# 53.17469120025635
# inside function
# 29.605584383010864
# inside function
# 35.159900188446045
# inside function
# 9.982448101043701
# 13.252734184265137
# 105.89445328712463
# inside function
# inside function
# inside function
# inside function
# inside function
# 19.659765005111694
# 47.45513725280762
# inside function
# 58.74613809585571
# inside function
# inside function
# 13.330646991729736
# inside function
# inside function
# inside function
# inside function
# inside function
# 71.44775342941284
# 49.58283567428589
# inside function
# inside function
# inside function
# 60.508121967315674
# inside function
# 44.03896951675415
# inside function
# 45.55442261695862
# 29.63585638999939
# 32.39328122138977
# inside function
# inside function
# inside function
# 45.777106523513794
# 25.544896364212036
# inside function
# inside function
# 42.38555383682251
# inside function
# 34.382723808288574
# inside function
# 115.24761128425598
# inside function
# 7.945704936981201
# inside function
# 57.71518635749817
# 39.76202416419983
# inside function
# inside function
# 40.825995206832886
# 30.1139817237854
# inside function
# 19.498610496520996
# inside function
# 21.056302309036255
# inside function
# 109.02047300338745
# inside function
# inside function
# inside function
# inside function
# inside function
# 27.523814916610718
# inside function
# 55.96297788619995
# inside function
# 57.84521842002869
# inside function
# 17.928752660751343
# inside function
# 99.04345273971558
# inside function
# 23.54521369934082
# inside function
# 90.18610548973083
# inside function
# 18.935025215148926
# inside function
# 13.412375688552856
# inside function
# 62.76094055175781
# inside function
# 11.777673959732056
# 11.715672254562378
# inside function
# 32.120530128479004
# 26.38427233695984
# inside function
# inside function
# inside function
# 27.996822595596313
# 8.879772663116455
# inside function
# inside function
# inside function
# 44.18855857849121
# inside function
# inside function
# 77.82078576087952
# 91.54822564125061
# inside function
# 17.569275379180908
# inside function
# 23.453259706497192
# 24.776500463485718
# 64.67576146125793
# inside function
# 80.93246603012085
# inside function
# inside function
# inside function
# inside function
# 69.44955229759216
# 96.24587178230286
# inside function
# 68.64510560035706
# 94.45373201370239
# inside function
# 62.64501404762268
# inside function
# 55.055782079696655
# inside function
# 30.850796461105347
# inside function
# inside function
# 37.482569456100464
# inside function
# inside function
# 41.749791383743286
# inside function
# 85.66940832138062
# 144.1212875843048
# inside function
# 36.0251190662384
# inside function
# 38.61421275138855
# inside function
# 15.450706481933594
# 25.822509765625
# 34.06140971183777
# inside function
# 12.690288066864014
# inside function
# 35.89135527610779
# 26.900275468826294
# inside function
# inside function
# inside function
# 123.07047319412231
# inside function
# 90.31424736976624
# inside function
# 37.83319926261902
# 25.347665548324585
# inside function
# inside function
# inside function
# inside function
# 84.34604382514954
# 111.08976244926453
# inside function
# inside function
# 45.55801177024841
# inside function
# 56.88735866546631
# inside function
# 33.39592361450195
# inside function
# 108.55311274528503
# inside function
# 127.47302722930908
# inside function
# inside function
# 55.695096492767334
# 25.421549320220947
# inside function
# 63.14144158363342
# inside function
# inside function
# 61.23032355308533
# inside function
# inside function
# 35.65003275871277
# 61.27177977561951
# inside function
# inside function
# 55.31758975982666
# 87.1703872680664
# 43.53781032562256
# inside function
# 11.734821557998657
# 44.69140124320984
# inside function
# inside function
# 23.755608320236206
# inside function
# 34.76771020889282
# inside function
# 42.08077359199524
# inside function
# 54.7204110622406
# inside function
# 115.47518849372864
# 35.08270311355591
# inside function
# inside function
# 17.639673948287964
# inside function
# 16.228853940963745
# inside function
# 28.267709255218506
# 106.68518805503845
# 74.26756954193115
# inside function
# 74.75981831550598
# 50.462347745895386
# inside function
# inside function
# 74.44564914703369
# inside function
# 50.83494424819946
# inside function
# inside function
# 49.963093280792236
# inside function
# 36.3462975025177
# inside function
# 46.69685411453247
# inside function
# 47.823792695999146
# inside function
# 9.524410486221313
# inside function
# 139.15777683258057
# 52.495665311813354
# inside function
# 30.756225109100342
# inside function
# inside function
# 38.538987159729004
# inside function
# 26.080264568328857
# inside function
# 33.70968842506409
# inside function
# inside function
# 74.19458413124084
# 27.074641942977905
# inside function
# 34.230297803878784
# inside function
# 60.72104501724243
# inside function
# inside function
# 86.24660205841064
# 36.956398725509644
# inside function
# 93.71150994300842
# 15.740200519561768
# inside function
# inside function
# inside function
# 63.775777101516724
# inside function
# 32.468567848205566
# inside function
# 118.18129324913025
# inside function
# 28.886393785476685
# inside function
# 23.64369249343872
# inside function
# 19.167378664016724
# inside function
# 85.94565033912659
# inside function
# 83.47529578208923
# inside function
# 53.178669929504395
# inside function
# 40.09062051773071
# inside function
# 65.43987894058228
# inside function
# inside function
# 28.63231348991394
# inside function
# 88.8831205368042
# inside function
# 183.0538170337677
# 37.44354748725891
# inside function
# 57.06117606163025
# inside function
# inside function
# 33.689178466796875
# inside function
# 65.70207738876343
# inside function
# 74.19653010368347
# inside function
# 76.49372696876526
# inside function
# 63.02898669242859
# inside function
# inside function
# 122.3123197555542
# 31.389094591140747
# inside function
# inside function
# inside function
# inside function
# inside function
# inside function
# 34.21732425689697
# inside function
# 44.64460635185242
# inside function
# 95.87771201133728
# inside function
# 43.251083850860596
# inside function
# 39.37187099456787
# 27.68704605102539
# inside function
# 41.868783950805664
# inside function
# inside function
# 31.133336782455444
# inside function
# 73.45766067504883
# inside function
# 59.55595421791077
# inside function
# 83.07869863510132
# inside function
# 29.712255477905273
# 45.68634843826294
# 120.2819094657898
# inside function
# inside function
# 60.58466911315918
# inside function
# 34.63232660293579
# 57.74907827377319
# inside function
# 88.92354035377502
# inside function
# 68.05540204048157
# inside function
# 31.314576387405396
# inside function
# 67.962327003479
# inside function
# 49.84955096244812
# inside function
# 122.7999939918518
# 38.670671224594116
# 37.821828842163086
# 80.6313841342926
# inside function
# inside function
# inside function
# 36.91763138771057
# inside function
# inside function
# 60.96510028839111
# inside function
# inside function
# 60.42292904853821
# inside function
# inside function
# 119.87518215179443
# 99.18069911003113
# 50.072458267211914
# inside function
# 115.89653134346008
# inside function
# inside function
# inside function
# inside function
# 21.00862169265747
# inside function
# 70.29356217384338
# inside function
# 47.14080286026001
# inside function
# 28.02253818511963
# inside function
# inside function
# 39.79661273956299
# inside function
# 62.08383369445801
# inside function
# 49.86788845062256
# 25.891292333602905
# inside function
# inside function
# 52.31388998031616
# inside function
# 33.169540882110596
# 63.072534799575806
# inside function
# 105.5685408115387
# 45.06562161445618
# inside function
# inside function
# 79.80224823951721
# inside function
# 59.820303440093994
# inside function
# 36.88714265823364
# inside function
# 55.73669171333313
# inside function
# 77.21462321281433
# inside function
# inside function
# inside function
# 76.67197227478027
# inside function
# 149.09368801116943
# inside function
# 21.50413489341736
# inside function
# 100.31408333778381
# inside function
# 78.26940131187439
# inside function
# 14.199136734008789
# inside function
# 53.33261728286743
# inside function
# 47.6913001537323
# inside function
# 99.44137239456177
# inside function
# 87.76247072219849
# 94.72210097312927
# 92.30312061309814
# inside function
# 75.89096713066101
# inside function
# inside function
# 122.22146344184875
# 43.858617305755615
# inside function
# inside function
# 21.381075620651245
# inside function
# 36.284199476242065
# inside function
# 119.70206356048584
# inside function
# 26.293617486953735
# inside function
# 33.72211790084839
# inside function
# 30.380779504776
# inside function
# 87.66276001930237
# inside function
# 33.9043927192688
# inside function
# inside function
# 72.575612783432
# inside function
# inside function
# inside function
# 59.39825105667114
# inside function
# 79.65235781669617
# inside function
# 26.67738103866577
# inside function
# 33.90975022315979
# inside function
# 26.12931203842163
# 43.642980098724365
# inside function
# inside function
# 14.63897180557251
# inside function
# 78.14319586753845
# inside function
# inside function
# inside function
# 72.12614846229553
# inside function
# 31.030149698257446
# inside function
# 50.08767795562744
# 21.43197989463806
# inside function
# 81.18133544921875
# 129.40131092071533
# inside function
# 80.2202787399292
# 44.341439723968506
# inside function
# inside function
# 106.62077951431274
# inside function
# 61.48270845413208
# inside function
# inside function
# 139.15115118026733
# inside function
# inside function
# 38.55219626426697
# inside function
# 40.7992479801178
# inside function
# 67.09662818908691
# inside function
# 22.76565980911255
# inside function
# 101.36602735519409
# inside function
# 90.36027455329895
# 86.56831955909729
# 58.42498207092285
# inside function
# inside function
# 39.730533599853516
# inside function
# 54.57600688934326
# 78.74971675872803
# inside function
# inside function
# inside function
# 28.150383234024048
# inside function
# 15.893397808074951
# inside function
# 121.19245672225952
# 27.044547080993652
# inside function
# inside function
# 34.294201612472534
# inside function
# 61.17102861404419
# inside function
# 68.33049464225769
# inside function
# 60.02520442008972
# inside function
# 64.23018097877502
# inside function
# 97.70553970336914
# inside function
# 59.93484663963318
# 25.94049644470215
# inside function
# 38.38493227958679
# inside function
# 17.092215538024902
# inside function
# 32.009318351745605
# inside function
# 9.758362293243408
# inside function
# 13.444641351699829
# inside function
# inside function
# 59.27644205093384
# 54.346808671951294
# inside function
# inside function
# 50.441171646118164
# inside function
# inside function
# 46.59177565574646
# inside function
# 77.46705460548401
# inside function
# 131.30968475341797
# inside function
# 102.09010767936707
# inside function
# 61.546627044677734
# inside function
# 28.880475521087646
# inside function
# 29.774484634399414
# inside function
# 68.78297877311707
# inside function
# 5.485270977020264
# inside function
# 45.253498554229736
# inside function
# 33.56612181663513
# inside function
# inside function
# 36.84189581871033
# inside function
# 50.80239701271057
# inside function
# inside function
# 131.9744644165039
# inside function
# 25.451871156692505
# inside function
# 60.923412799835205
# inside function
# 79.93313479423523
# inside function
# 88.69678544998169
# 51.12465858459473
# 71.33271956443787
# 68.92032146453857
# inside function
# 10.276567459106445
# inside function
# 119.64857864379883
# inside function
# inside function
# 37.265907526016235
# inside function
# 103.0481493473053
# inside function
# 35.16764545440674
# inside function
# 52.368929386138916
# inside function
# 49.57573413848877
# inside function
# 33.98407530784607
# inside function
# 133.8645145893097
# inside function
# 86.45956444740295
# inside function
# 36.500571489334106
# inside function
# 77.22082090377808
# inside function
# 14.758474588394165
# inside function
# 18.680728435516357
# inside function
# 90.38135838508606
# inside function
# 100.1854944229126
# 7.200493574142456
# inside function
# inside function
# 6.815462827682495
# inside function
# inside function
# 19.587480068206787
# inside function
# inside function
# 110.29637217521667
# inside function
# 46.898361682891846
# inside function
# 27.7433819770813
# inside function
# 45.12416934967041
# 58.13186764717102
# 62.411320209503174
# inside function
# inside function
# 107.09889793395996
# 49.14691162109375
# inside function
# inside function
# 81.92038488388062
# inside function
# inside function
# 15.519448518753052
# 131.66556215286255
# inside function
# inside function
# 82.82995867729187
# 25.148736715316772
# inside function
# inside function
# inside function
# 32.88802361488342
# inside function
# 101.48587274551392
# inside function
# 51.07510328292847
# 57.01740050315857
# inside function
# 79.39972591400146
# 105.88533210754395
# inside function
# inside function
# 85.96445822715759
# inside function
# 68.0155303478241
# 92.34222745895386
# inside function
# 28.85635805130005
# inside function
# inside function
# 55.82831406593323
# inside function
# 59.23782658576965
# inside function
# 38.644755363464355
# inside function
# 81.76698231697083
# 124.90353918075562
# inside function
# 30.305920362472534
# inside function
# inside function
# 108.76775312423706
# 46.232078552246094
# inside function
# 96.6298758983612
# inside function
# 181.6096465587616
# inside function
# inside function
# 56.91306209564209
# inside function
# inside function
# 44.86145853996277
# inside function
# 92.18422532081604
# inside function
# 30.668410539627075
# inside function
# 74.82917833328247
# 10.017132759094238
# inside function
# inside function
# 112.89177060127258
# 50.55845832824707
# inside function
# inside function
# 57.079355239868164
# inside function
# 79.6956729888916
# inside function
# 106.36315989494324
# 51.46218800544739
# inside function
# inside function
# 76.28871417045593
# inside function
# inside function
# 93.10161781311035
# 59.60633325576782
# inside function
# 39.19075679779053
# inside function
# inside function
# 62.66672468185425
# 52.94650864601135
# inside function
# inside function
# 88.84643650054932
# inside function
# 91.91247797012329
# inside function
# 118.045081615448
# 24.82746124267578
# 139.26513528823853
# inside function
# 84.1582841873169
# inside function
# inside function
# 60.80393052101135
# inside function
# inside function
# 52.41680288314819
# inside function
# 55.078802824020386
# 47.69392251968384
# inside function
# inside function
# 117.4062831401825
# inside function
# 113.5355749130249
# 25.636120796203613
# inside function
# 24.754356622695923
# inside function
# inside function
# 88.86202836036682
# inside function
# 12.894723415374756
# 73.378089427948
# inside function
# inside function
# inside function
# inside function
# 116.71933174133301
# inside function
# 82.0281138420105
# inside function
# 62.76412105560303
# inside function
# 95.60951590538025
# inside function
# 61.822718381881714
# 110.8852379322052
# 66.50176668167114
# 65.03081607818604
# inside function
# inside function
# 64.80817747116089
# inside function
# inside function
# inside function
# 16.45941710472107
# inside function
# 41.90601634979248
# inside function
# 66.58926391601562
# inside function
# 17.103450298309326
# inside function
# 39.32928419113159
# 68.69725632667542
# 68.69339776039124
# inside function
# 66.91720986366272
# inside function
# inside function
# 15.016281366348267
# inside function
# inside function
# 123.52299952507019
# inside function
# 64.47485637664795
# inside function
# 31.454234838485718
# 76.22632098197937
# inside function
# 44.080241441726685
# inside function
# 42.561927318573
# inside function
# inside function
# inside function
# 26.821534156799316
# 85.06783366203308
# inside function
# inside function
# 50.23234534263611
# inside function
# inside function
# 33.370826959609985
# 183.53810286521912
# 128.81120133399963
# inside function
# inside function
# 20.010298490524292
# inside function
# 72.23946976661682
# inside function
# 63.20867371559143
# 16.81856060028076
# 74.13050961494446
# inside function
# inside function
# 94.26865863800049
# inside function
# 101.56412243843079
# inside function
# 104.079092502594
# inside function
# 147.26051568984985
# inside function
# 57.51960301399231
# 40.31485462188721
# inside function
# 67.30307650566101
# 27.57610297203064
# inside function
# 75.28709125518799
# inside function
# 53.685343742370605
# inside function
# inside function
# inside function
# 62.69955492019653
# inside function
# inside function
# 72.1585910320282
# 99.35645198822021
# inside function
# inside function
# 91.36227655410767
# inside function
# 96.57772064208984
# inside function
# inside function
# 28.458409786224365
# inside function
# 28.008452653884888
# inside function
# 11.08191728591919
# inside function
# 66.13855075836182
# inside function
# 110.70416808128357
# 71.55060482025146
# inside function
# 58.619502544403076
# inside function
# 72.05290293693542
# 43.540926456451416
# inside function
# 17.05094337463379
# inside function
# 78.97943925857544
# inside function
# inside function
# inside function
# 64.06371140480042
# 85.64326524734497
# inside function
# 174.51819252967834
# inside function
# inside function
# 39.02954125404358
# 71.89204692840576
# inside function
# 64.17975306510925
# inside function
# 14.437397003173828
# inside function
# inside function
# 122.98290801048279
# inside function
# 37.72100877761841
# 86.65409278869629
# inside function
# inside function
# inside function
# 96.01929926872253
# inside function
# 18.96255326271057
# 88.99236869812012
# inside function
# 79.54702162742615
# inside function
# 96.92118906974792
# inside function
# 104.3385283946991
# inside function
# 47.69728684425354
# inside function
# 62.43078804016113
# inside function
# 73.84453821182251
# inside function
# 68.74549555778503
# inside function
# 116.43782567977905
# inside function
# 56.46122884750366
# 68.10318517684937
# inside function
# 87.44941782951355
# inside function
# inside function
# 32.142425537109375
# inside function
# 52.94030952453613
# inside function
# 50.01587390899658
# 78.81181716918945
# inside function
# inside function
# inside function
# 9.862539291381836
# inside function
# 92.82355213165283
# inside function
# 63.381726026535034
# inside function
# 88.38374996185303
# inside function
# 24.68860626220703
# 80.39358806610107
# inside function
# 99.15819883346558
# inside function
# 137.40010023117065
# 164.25864124298096
# inside function
# inside function
# 137.97436022758484
# 55.31239891052246
# inside function
# 57.04699182510376
# inside function
# 59.75640559196472
# inside function
# 51.06453514099121
# 59.89409041404724
# inside function
# inside function
# 10.596313714981079
# inside function
# 87.20705199241638
# inside function
# 28.415225744247437
# inside function
# inside function
# 105.94056177139282
# 66.09357738494873
# inside function
# 22.043447494506836
# 36.574257373809814
# inside function
# 23.72112274169922
# inside function
# inside function
# 35.69652080535889
# 74.04719233512878
# 59.27627515792847
# inside function
# inside function
# inside function
# 42.587260246276855
# inside function
# 164.48329401016235
# 192.21481919288635
# inside function
# 28.876890897750854
# 72.40819501876831
# inside function
# inside function
# 109.15122318267822
# inside function
# 77.08838152885437
# inside function
# 80.10434865951538
# inside function
# inside function
# 61.2370388507843
# 167.04043006896973
# inside function
# 88.280118227005
# 102.21601390838623
# inside function
# 83.29970097541809
# inside function
# 48.619911432266235
# inside function
# inside function
# inside function
# 84.5317633152008
# 98.40675520896912
# inside function
# inside function
# 44.86561560630798
# inside function
# 74.94404768943787
# 88.81559491157532
# inside function
# 78.65892744064331
# inside function
# 66.77772903442383
# 67.3221070766449
# inside function
# inside function
# inside function
# 58.88737964630127
# inside function
# 84.75886678695679
# inside function
# 75.61581373214722
# 156.98216700553894
# inside function
# 74.66888380050659
# inside function
# inside function
# 72.25973057746887
# 105.42667150497437
# inside function
# 64.33386516571045
# inside function
# 96.80094981193542
# inside function
# inside function
# 96.06967186927795
# 78.72764539718628
# inside function
# inside function
# 53.57797408103943
# 118.75996541976929
# inside function
# 62.995076417922974
# inside function
# 86.72135210037231
# inside function
# 81.22280216217041
# inside function
# inside function
# 88.73320746421814
# inside function
# 26.659880876541138
# inside function
# inside function
# inside function
# inside function
# 62.28463912010193
# inside function
# 99.87302160263062
# inside function
# 50.64676332473755
# inside function
# 75.79497194290161
# inside function
# 27.372488737106323
# inside function
# 72.74139523506165
# inside function
# 122.95723271369934
# inside function
# 65.67685794830322
# inside function
# 62.24628806114197
# inside function
# 68.10350584983826
# inside function
# 136.492534160614
# 91.14633202552795
# inside function
# inside function
# 82.7197835445404
# inside function
# 68.6923131942749
# inside function
# 70.90855121612549
# inside function
# 117.038419008255
# inside function
# 91.17996954917908
# 96.31250834465027
# inside function
# inside function
# 51.29556155204773
# inside function
# 137.67789316177368
# inside function
# 126.3044683933258
# inside function
# 74.57963705062866
# inside function
# 115.91019606590271
# inside function
# 75.4012758731842
# 41.15385890007019
# inside function
# 85.78118538856506
# inside function
# inside function
# inside function
# 105.39829516410828
# inside function
# 93.46280980110168
# inside function
# 38.828903913497925
# inside function
# 57.96395301818848
# inside function
# 105.62996244430542
# inside function
# 129.56836652755737
# inside function
# 91.6813268661499
# inside function
# 155.80460023880005
# 95.15116095542908
# inside function
# 72.90215921401978
# inside function
# inside function
# 100.55056071281433
# inside function
# 67.44323945045471
# inside function
# 64.54495191574097
# inside function
# 67.0694637298584
# inside function
# inside function
# 59.2036235332489
# 69.56576180458069
# 172.3893322944641
# 21.642913341522217
# inside function
# inside function
# 21.905468463897705
# inside function
# 48.99048614501953
# 79.03919196128845
# inside function
# inside function
# inside function
# 104.73980283737183
# 69.00453972816467
# 88.42071175575256
# inside function
# inside function
# 27.630698919296265
# 76.2190489768982
# inside function
# inside function
# inside function
# 63.982619285583496
# inside function
# 73.8858950138092
# inside function
# inside function
# 35.91778802871704
# 31.615182876586914
# inside function
# inside function
# inside function
# 66.9960355758667
# inside function
# 255.18961095809937
# 66.67649984359741
# 215.14098620414734
# 41.86441922187805
# inside function
# inside function
# inside function
# 52.92739963531494
# inside function
# 135.00878620147705
# inside function
# 35.582985401153564
# 30.571285247802734
# inside function
# 109.87211012840271
# inside function
# inside function
# inside function
# 76.25270485877991
# inside function
# 90.3802216053009
# inside function
# 73.81725454330444
# inside function
# 215.77066278457642
# 93.5806987285614
# inside function
# 84.71036005020142
# inside function
# 146.28813815116882
# inside function
# 213.07077622413635
# inside function
# 88.47123098373413
# inside function
# 80.85685563087463
# inside function
# 25.098405361175537
# inside function
# 95.6274516582489
# 30.389040231704712
# inside function
# inside function
# inside function
# 115.72550058364868
# inside function
# 180.47863721847534
# inside function
# 123.32562708854675
# inside function
# 249.5645501613617
# inside function
# 38.44660425186157
# 86.03895616531372
# inside function
# inside function
# 54.92486238479614
# inside function
# 93.31176733970642
# inside function
# 81.5336127281189
# 75.82601833343506
# inside function
# 37.94362473487854
# inside function
# 70.7206540107727
# inside function
# inside function
# inside function
# 50.09063911437988
# inside function
# inside function
# inside function
# 113.50668787956238
# 145.15967893600464
# inside function
# inside function
# inside function
# 141.11537432670593
# 206.69316458702087
# 126.91774892807007
# inside function
# inside function
# 40.05417728424072
# 45.155105113983154
# inside function
# 124.08735752105713
# inside function
# 83.84982919692993
# inside function
# 175.27950048446655
# inside function
# 100.6893482208252
# inside function
# 124.3187038898468
# 49.264869689941406
# inside function
# inside function
# inside function
# 53.438899993896484
# inside function
# 78.7507815361023
# inside function
# 74.63806056976318
# 72.78301525115967
# inside function
# 102.02633237838745
# inside function
# 83.82100033760071
# inside function
# 26.476930141448975
# inside function
# 164.43925094604492
# inside function
# inside function
# 115.33750104904175
# inside function
# 34.16877746582031
# inside function
# 179.06405091285706
# 56.8969931602478
# inside function
# inside function
# 60.24665379524231
# inside function
# 125.56436228752136
# inside function
# inside function
# 53.84190320968628
# inside function
# 102.01509833335876
# inside function
# 96.94984579086304
# 53.26474642753601
# inside function
# 116.69410943984985
# inside function
# 92.96975135803223
# inside function
# 161.3972680568695
# 117.9088876247406
# 58.79301738739014
# inside function
# 126.25140833854675
# inside function
# inside function
# inside function
# 64.88494038581848
# inside function
# 31.36759042739868
# inside function
# inside function
# 124.67962312698364
# inside function
# 107.55516314506531
# inside function
# 78.89199662208557
# inside function
# inside function
# 113.46020555496216
# 58.31696605682373
# inside function
# 171.23526978492737
# 45.65865731239319
# inside function
# 35.032975912094116
# 88.73657131195068
# inside function
# inside function
# 48.92599821090698
# inside function
# inside function
# 104.37178015708923
# inside function
# inside function
# 183.28363227844238
# 144.0875642299652
# 43.87494373321533
# inside function
# inside function
# 34.99755907058716
# 169.87233567237854
# 113.95499277114868
# inside function
# inside function
# 113.25646781921387
# inside function
# 76.61304974555969
# 128.70035362243652
# inside function
# inside function
# 79.1148841381073
# inside function
# inside function
# inside function
# inside function
# 101.31568217277527
# inside function
# 88.4012815952301
# 64.7045910358429
# 126.22042536735535
# inside function
# inside function
# 139.48024034500122
# inside function
# inside function
# inside function
# 99.37511038780212
# inside function
# 61.50777196884155
# 133.9330461025238
# 65.66059637069702
# 101.7335638999939
# inside function
# 103.63409781455994
# inside function
# inside function
# inside function
# inside function
# 33.021387577056885
# inside function
# 79.62268614768982
# 24.96548342704773
# inside function
# 171.73379468917847
# inside function
# 72.44943284988403
# inside function
# 121.68299674987793
# 105.60718250274658
# inside function
# 99.8605170249939
# inside function
# 48.11685562133789
# inside function
# 27.398449897766113
# 49.929638147354126
# inside function
# inside function
# inside function
# 65.18982648849487
# inside function
# 51.124661445617676
# inside function
# 26.474433183670044
# inside function
# 163.38888597488403
# inside function
# inside function
# 50.415095806121826
# inside function
# inside function
# 31.892070770263672
# inside function
# 97.58251667022705
# inside function
# 106.2743456363678
# inside function
# 130.05661845207214
# inside function
# inside function
# inside function
# inside function
# inside function
# inside function
# inside function
# inside function
# 36.538885831832886
# inside function
# 190.1915545463562
# inside function
# inside function
# 36.48627495765686
# 53.595924615859985
# inside function
# inside function
# 90.25994229316711
# 101.68695902824402
# 139.530033826828
# inside function
# 75.81087279319763
# inside function
# inside function
# 57.34498643875122
# inside function
# 45.798903703689575
# inside function
# 79.913583278656
# inside function
# 211.0534417629242
# inside function
# 74.49784994125366
# 91.93853712081909
# 156.95214366912842
# inside function
# inside function
# inside function
# 87.79653596878052
# inside function
# 68.16411852836609
# inside function
# inside function
# 92.08738780021667
# 126.42443132400513
# 82.347825050354
# inside function
# 147.61848521232605
# 73.93117713928223
# inside function
# inside function
# 105.82278847694397
# inside function
# inside function
# inside function
# 95.35934829711914
# inside function
# 129.59352445602417
# 111.94577860832214
# inside function
# inside function
# 80.5135235786438
# 64.37629914283752
# inside function
# inside function
# 73.14703798294067
# 118.50043964385986
# inside function
# 96.12148523330688
# inside function
# 167.50794386863708
# inside function
# 85.06965970993042
# 93.2649598121643
# 87.6635537147522
# inside function
# inside function
# inside function
# inside function
# inside function
# inside function
# 81.69145059585571
# 115.31450986862183
# inside function
# 172.79623317718506
# 119.5438928604126
# inside function
# inside function
# 98.91955828666687
# 53.79080820083618
# inside function
# inside function
# inside function
# 67.47965383529663
# inside function
# 32.75199294090271
# inside function
# 108.22717356681824
# 77.2660927772522
# inside function
# inside function
# 124.10745549201965
# inside function
# 137.430997133255
# inside function
# 151.84658074378967
# 78.82267427444458
# 81.07334089279175
# inside function
# 58.148422718048096
# inside function
# 55.63820219039917
# 165.84788584709167
# 137.80125069618225
# inside function
# inside function
# 98.42945051193237
# inside function
# 101.84481000900269
# inside function
# 17.882827281951904
# inside function
# 125.36504650115967
# inside function
# 85.37924218177795
# 90.89562749862671
# inside function
# 183.72620177268982
# inside function
# inside function
# 81.72264838218689
# inside function
# 114.36620759963989
# inside function
# inside function
# 102.6684410572052
# inside function
# 88.28325152397156
# inside function
# 46.06066393852234
# inside function
# 86.07479071617126
# inside function
# inside function
# 68.34119582176208
# inside function
# 101.59780430793762
# 29.358795642852783
# inside function
# inside function
# 74.35681796073914
# 182.49932408332825
# 161.72253370285034
# 59.328999280929565
# inside function
# 111.084055185318
# 62.87845158576965
# inside function
# 87.6888370513916
# 59.867923736572266
# inside function
# inside function
# inside function
# 119.224609375
# inside function
# inside function
# 158.5566282272339
# inside function
# inside function
# 217.53598475456238
# 64.78255128860474
# inside function
# 133.01467204093933
# inside function
# 145.51323795318604
# inside function
# inside function
# inside function
# 76.12400722503662
# inside function
# 105.52197027206421
# 43.78944754600525
# 115.69615602493286
# inside function
# 124.43239712715149
# inside function
# 84.08374285697937
# inside function
# inside function
# inside function
# 71.79507660865784
# 51.88765549659729
# inside function
# 90.42928194999695
# 93.11255764961243
# inside function
# inside function
# 76.83620238304138
# inside function
# 89.56246280670166
# inside function
# 90.83536434173584
# inside function
# 128.6296248435974
# inside function
# 78.03732299804688
# inside function
# 100.17079186439514
# inside function
# 70.96745324134827
# inside function
# 119.45972561836243
# 53.74127531051636
# inside function
# 80.66647386550903
# inside function
# inside function
# 63.54706168174744
# inside function
# inside function
# inside function
# 10.644883394241333
# inside function
# 52.64959931373596
# 105.18010115623474
# inside function
# 128.17620944976807
# 123.77606868743896
# inside function
# inside function
# 112.47356367111206
# inside function
# 137.44766783714294
# inside function
# 19.588093519210815
# 52.87655735015869
# inside function
# inside function
# 87.86582374572754
# inside function
# 100.33073329925537
# inside function
# 121.6166889667511
# 33.183412075042725
# inside function
# 34.22111248970032
# inside function
# 71.80426454544067
# inside function
# inside function
# inside function
# 82.18379592895508
# inside function
# 141.70359063148499
# inside function
# 296.55746722221375
# inside function
# 80.03332781791687
# 17.3838312625885
# inside function
# inside function
# 183.8921582698822
# 243.44132661819458
# 151.7729151248932
# inside function
# 74.86979126930237
# inside function
# 43.45809817314148
# inside function
# inside function
# 21.822651624679565
# 41.99077248573303
# inside function
# 40.32450604438782
# inside function
# inside function
# inside function
# 110.37889289855957
# inside function
# inside function
# 96.16232657432556
# inside function
# 293.5587911605835
# inside function
# 97.78044033050537
# inside function
# 171.9432373046875
# inside function
# 51.46135210990906
# inside function
# 84.14584255218506
# inside function
# 50.58346962928772
# inside function
# 125.40826392173767
# ...
# 112.95431613922119
# inside function
# 70.81855583190918
# inside function
# 113.14873051643372
# inside function
# 345.3469076156616
# 48.66338515281677
# inside function
# 189.81165528297424
# inside function
# 80.17343878746033
# inside function
# 42.93792915344238
# inside function
# 106.33712148666382
# inside function
# 182.93011116981506
# inside function
# 192.1946210861206
# inside function
# 381.49885749816895
# inside function
# 95.3169515132904
# inside function
# 238.4792664051056
# inside function
# 322.113689661026
# inside function
# inside function
# inside function
# 94.61058449745178
# inside function
# 150.34802985191345
# inside function
# 404.13056540489197
# inside function
# 302.50893926620483
# inside function
# 383.46143865585327
# inside function
# 169.54140520095825
# inside function
# 106.1071515083313
# inside function
# 449.8956649303436
# 70.45844793319702
# inside function
# inside function
# 529.7602076530457
# inside function
# 180.271502494812
# inside function
# 262.02258229255676
# inside function
# 132.44010019302368
# 149.75609874725342
# inside function
# 217.91743087768555
# inside function
# 169.38900446891785
# inside function
# 222.98493194580078
# inside function
# 125.56498146057129
# 181.99007201194763
# inside function
# 91.58426928520203
# inside function
# 195.04928350448608
# inside function
# 96.45282912254333
# inside function
# 178.67408514022827
# inside function
# 24.586336135864258
# inside function
# 122.58794045448303
# inside function
# 162.75327682495117
# inside function
# 330.65242409706116
# inside function
# 507.08520770072937
# 137.0573525428772
# inside function
# 56.70678973197937
# inside function
# 77.87166953086853
# inside function
# 242.856285572052
# inside function
# 107.81988525390625
# inside function
# 220.8180034160614
# inside function
# 339.47004556655884
# inside function
# 279.78357553482056
# inside function
# 353.88164472579956
# inside function
# 32.36265230178833
# inside function
# 193.8537561893463
# inside function
# 89.06246304512024
# inside function
# 676.0921981334686
# inside function
# 119.60412573814392
# inside function
# 95.79696345329285
# inside function
# 210.00694227218628
# inside function
# 228.2177004814148
# inside function
# 128.13179421424866
# 390.7931046485901
# inside function
# inside function
# 109.61213111877441
# inside function
# 270.52050709724426
# inside function
# 230.81818985939026
# inside function
# 380.2377953529358
# inside function
# 295.74107336997986
# inside function
# 297.92271971702576
# inside function
# 244.86305260658264
# inside function
# inside function
# 36.91929650306702
# inside function
# 124.45753693580627
# inside function
# 117.24592280387878
# 94.69039106369019
# inside function
# inside function
# 218.19788026809692
# inside function
# 123.75918936729431
# inside function
# 134.92128086090088
# inside function
# 112.91057419776917
# inside function
# 156.0827760696411
# inside function
# 104.26174426078796
# inside function
# 108.63978886604309
# inside function
# 252.81303334236145
# inside function
# 83.47843766212463
# inside function
# 67.47695875167847
# 50.08046507835388
# 116.62500715255737
# inside function
# 21.692375421524048
# inside function
# 226.1012146472931
# inside function
# 335.4003858566284
# inside function
# 81.8349061012268
# inside function
# 311.80641055107117
# inside function
# 58.81121325492859
# inside function
# inside function
# 163.97705793380737
# inside function
# 101.49810910224915
# inside function
# 229.29001355171204
# inside function
# 115.4088351726532
# inside function
# 325.8558506965637
# inside function
# 81.48139333724976
# inside function
# 219.35568690299988
# inside function
# 378.5229365825653
# inside function
# 70.82306265830994
# inside function
# 172.59729409217834
# inside function
# 204.94051814079285
# inside function
# 253.41388869285583
# inside function
# 306.30171036720276
# inside function
# 90.24573969841003
# inside function
# 114.11035299301147
# inside function
# 112.51830172538757
# inside function
# 354.7563564777374
# 170.67252564430237
# inside function
# inside function
# 401.85550594329834
# inside function
# 123.64968514442444
# inside function
# 171.74177956581116
# inside function
# 124.19963526725769
# inside function
# 280.85251212120056
# inside function
# 163.41688013076782
# inside function
# 119.92805504798889
# inside function
# 84.0475401878357
# inside function
# 182.7246286869049
# inside function
# 320.6747558116913
# inside function
# 142.8927652835846
# inside function
# 184.43041920661926
# inside function
# 73.33428883552551
# inside function
# 288.87608766555786
# inside function
# 229.57216262817383
# inside function
# 484.57554149627686
# inside function
# 31.72437858581543
# inside function
# 199.81119775772095
# inside function
# 92.09412026405334
# inside function
# 41.75367069244385
# inside function
# 374.30403876304626
# inside function
# inside function
# 260.9311468601227
# inside function
# 121.94539546966553
# inside function
# 143.49480271339417
# inside function
# 194.62956500053406
# inside function
# 80.07003211975098
# inside function
# 24.65905261039734
# inside function
# 358.81140208244324
# inside function
# 87.86429977416992
# inside function
# 134.38424587249756
# inside function
# 78.06743741035461
# inside function
# 389.38074135780334
# inside function
# 198.48830676078796
# inside function
# 232.81364059448242
# inside function
# 224.06378555297852
# inside function
# 157.64096689224243
# 250.14666986465454
# inside function
# inside function
# 95.38656878471375
# inside function
# 66.10975193977356
# inside function
# 128.22419500350952
# inside function
# 162.27115631103516
# inside function
# 30.782737731933594
# inside function
# 170.7972869873047
# inside function
# 154.76616406440735
# inside function
# 66.00057363510132
# inside function
# 198.15457797050476
# inside function
# 92.0245885848999
# inside function
# 175.71803903579712
# inside function
# 152.6680977344513
# inside function
# 208.96742463111877
# inside function
# 248.6791341304779
# inside function
# 47.03831124305725
# inside function
# inside function
# 500.59278893470764
# inside function
# 254.9494755268097
# inside function
# 59.409581899642944
# inside function
# 108.08516263961792
# inside function
# 101.58150100708008
# inside function
# 248.94448471069336
# inside function
# 99.17188286781311
# inside function
# 349.6012797355652
# 492.0748574733734
# inside function
# inside function
# 236.2665901184082
# inside function
# 59.78956437110901
# inside function
# inside function
# 50.584325551986694
# inside function
# 266.62719464302063
# inside function
# 245.3885407447815
# inside function
# 37.39889478683472
# inside function
# 161.80388927459717
# inside function
# 120.40275430679321
# inside function
# 210.9458932876587
# inside function
# 71.74717164039612
# inside function
# 539.4968185424805
# inside function
# 66.39927196502686
# inside function
# 296.88224387168884
# inside function
# 282.8080704212189
# inside function
# 255.2875988483429
# inside function
# 193.03584957122803
# inside function
# 109.71823024749756
# inside function
# 111.12715268135071
# inside function
# 212.04645824432373
# inside function
# 283.9707221984863
# inside function
# 296.5785381793976
# inside function
# 182.80366230010986
# inside function
# 44.195825815200806
# inside function
# 238.42735314369202
# 93.85893726348877
# inside function
# inside function
# 143.53275537490845
# 41.256126165390015
# inside function
# inside function
# 345.2419466972351
# inside function
# 201.77093148231506
# inside function
# 139.3460192680359
# 161.17266726493835
# inside function
# inside function
# 55.91447043418884
# inside function
# 172.8057370185852
# inside function
# 129.44406938552856
# inside function
# 264.2989909648895
# inside function
# 322.71079683303833
# 403.72124552726746
# inside function
# 123.089839220047
# inside function
# 96.33385181427002
# inside function
# 135.07321310043335
# inside function
# 217.461585521698
# inside function
# 360.4257171154022
# inside function
# 90.4942877292633
# inside function
# 190.9821970462799
# inside function
# 165.79217100143433
# inside function
# 90.42498278617859
# inside function
# 82.9264976978302
# inside function
# 126.35570096969604
# inside function
# 380.20790243148804
# inside function
# 186.54405236244202
# 70.20284295082092
# 176.40476369857788
# inside function
# 192.10847687721252
# inside function
# 189.45035791397095
# inside function
# 74.12904405593872
# inside function
# 141.40307998657227
# 228.67256927490234
# inside function
# 100.29434108734131
# inside function
# 42.30718016624451
# inside function
# 214.81458616256714
# 102.4560375213623
# inside function
# inside function
# 226.35869932174683
# inside function
# 458.9062075614929
# inside function
# 413.7458481788635
# inside function
# 315.7327036857605
# 102.85983872413635
# inside function
# 292.8802137374878
# inside function
# inside function
# 119.16542506217957
# inside function
# 160.97500038146973
# inside function
# 85.2854573726654
# inside function
# 99.02794027328491
# inside function
# 147.96750283241272
# inside function
# 117.86528301239014
# inside function
# 119.21215581893921
# inside function
# 182.68723917007446
# inside function
# 130.5208797454834
# inside function
# 302.3251895904541
# inside function
# 171.27942180633545
# inside function
# 340.77361512184143
# inside function
# 152.49414682388306
# 78.66046118736267
# inside function
# inside function
# 208.77734541893005
# 98.38839483261108
# inside function
# 120.07723116874695
# inside function
# inside function
# 104.75081014633179
# inside function
# 93.68824315071106
# inside function
# 108.9740879535675
# inside function
# 296.6645338535309
# inside function
# 99.57690095901489
# inside function
# 258.5596432685852
# inside function
# 199.01745295524597
# inside function
# 257.4694724082947
# inside function
# 246.87522387504578
# 65.17443418502808
# inside function
# 56.36701726913452
# inside function
# 109.54461121559143
# inside function
# 252.76572394371033
# 241.59168243408203
# inside function
# 70.27765965461731
# inside function
# 97.09216165542603
# inside function
# 146.89740419387817
# inside function
# 237.69204759597778
# inside function
# 167.0573513507843
# 90.21466112136841
# inside function
# inside function
# 123.36503791809082
# inside function
# 186.27629470825195
# inside function
# 39.17029571533203
# 313.51157450675964
# 158.60356068611145
# inside function
# inside function
# 61.46600914001465
# inside function
# 158.62874364852905
# 259.43341612815857
# inside function
# inside function
# 29.834723472595215
# inside function
# 226.91125512123108
# 36.21181082725525
# inside function
# 56.03339076042175
# inside function
# inside function
# 94.00094723701477
# inside function
# 129.0833342075348
# inside function
# 51.60810160636902
# inside function
# 226.77282977104187
# inside function
# 128.73730611801147
# inside function
# 77.88589262962341
# inside function
# 313.4943037033081
# inside function
# 188.08228850364685
# inside function
# 84.96640229225159
# inside function
# 64.31498980522156
# inside function
# 185.0772831439972
# inside function
# 198.1462881565094
# inside function
# 178.58954048156738
# inside function
# 204.53689217567444
# inside function
# 184.72581100463867
# 155.22717547416687
# inside function
# inside function
# 94.75428915023804
# inside function
# 95.18441152572632
# inside function
# 91.4073965549469
# inside function
# 160.91044330596924
# inside function
# 147.86749505996704
# inside function
# 229.52784752845764
# inside function
# 134.27722573280334
# inside function
# 79.42120742797852
# 89.58835339546204
# inside function
# 219.8438491821289
# inside function
# 160.9399962425232
# inside function
# 85.13858270645142
# inside function
# 114.20214676856995
# inside function
# 161.30474042892456
# inside function
# 56.79271483421326
# inside function
# 122.6729154586792
# inside function
# 247.05686688423157
# inside function
# 125.57121992111206
# inside function
# 28.713111639022827
# inside function
# 112.06278324127197
# inside function
# 226.93125414848328
# inside function
# 42.81831336021423
# inside function
# 76.57162046432495
# inside function
# 102.85403323173523
# inside function
# 132.60274243354797
# inside function
# 114.38718295097351
# inside function
# 79.97243881225586
# inside function
# 112.53094863891602
# inside function
# 317.68835949897766
# inside function
# 60.37859582901001
# inside function
# 41.496025800704956
# inside function
# 187.34472918510437
# inside function
# 185.61342477798462
# inside function
# 77.45342755317688
# 70.41190457344055
# inside function
# 248.13931965827942
# inside function
# 51.00447988510132
# inside function
# 122.75277423858643
# inside function
# 121.39418029785156
# inside function
# 267.9055104255676
# inside function
# 186.68885564804077
# inside function
# 66.15179109573364
# inside function
# 39.37939763069153
# inside function
# 53.96346116065979
# 219.66766476631165
# inside function
# inside function
# 60.87523865699768
# inside function
# 141.53883576393127
# inside function
# inside function
# 213.5827739238739
# inside function
# 84.51665544509888
# 221.26022839546204
# inside function
# inside function
# 94.54168200492859
# inside function
# 156.60280013084412
# inside function
# 125.33759903907776
# 65.15809941291809
# inside function
# inside function
# 169.03320026397705
# inside function
# 53.345866680145264
# inside function
# 94.31358480453491
# inside function
# inside function
# 95.78033566474915
# inside function
# 72.15598726272583
# inside function
# 145.48899173736572
# inside function
# 162.59345865249634
# inside function
# 165.03190779685974
# 32.81612467765808
# inside function
# 63.70960187911987
# inside function
# 107.65773916244507
# inside function
# 73.98042321205139
# inside function
# 131.74670505523682
# inside function
# 138.503488779068
# inside function
# 119.48640322685242
# inside function
# 89.46586322784424
# inside function
# 152.11486864089966
# inside function
# 63.78100252151489
# inside function
# 123.63749194145203
# inside function
# 79.15010952949524
# inside function
# 61.75188207626343
# inside function
# 100.35807538032532
# inside function
# 122.92812848091125
# inside function
# 100.66990828514099
# inside function
# 159.4838044643402
# inside function
# 102.86125826835632
# inside function
# 49.07355761528015
# inside function
# 77.51227879524231
# inside function
# 117.00557279586792
# inside function
# 66.13504815101624
# inside function
# 95.3299171924591
# inside function
# 143.5692629814148
# 66.75232720375061
# inside function
# inside function
# 127.77302408218384
# inside function
# 56.89915060997009
# 198.77105498313904
# inside function
# 73.75687623023987
# inside function
# 93.58826780319214
# inside function
# 107.89678120613098
# inside function
# 54.610092639923096
# inside function
# 65.82146310806274
# inside function
# 85.60192465782166
# inside function
# 69.11020493507385
# inside function
# 26.821443557739258
# 93.18963503837585
# inside function
# 114.14503645896912
# inside function
# 141.06790828704834
# inside function
# 137.51617765426636
# inside function
# 99.88481259346008
# inside function
# 56.774272203445435
# inside function
# 39.34020733833313
# inside function
# 92.14078855514526
# 119.4698498249054
# inside function
# 25.658510208129883
# inside function
# 114.45800352096558
# inside function
# 25.357542991638184
# inside function
# 60.83545255661011
# inside function
# 58.580390214920044
# inside function
# 49.477463245391846
# inside function
# 59.928611516952515
# inside function
# 141.92465615272522
# inside function
# 26.009506702423096
# inside function
# 81.5430498123169
# 91.65098285675049
# inside function
# 71.16504693031311
# inside function
# 20.433079957962036
# inside function
# 57.809441804885864
# inside function
# 138.12890195846558
# inside function
# 46.908504247665405
# inside function
# 49.788960218429565
# 69.82860732078552
# inside function
# 58.2454617023468
# 64.78405809402466
# inside function
# 37.2934730052948
# inside function
# 58.704716205596924
# inside function
# 62.52684783935547
# inside function
# 21.163355827331543
# inside function
# 41.41574311256409
# inside function
# 30.99593949317932
# inside function
# 37.49985933303833
# inside function
# 38.96891403198242
# inside function
# 46.454411029815674
# inside function
# 32.79157900810242
# inside function
# 42.63420605659485
# inside function
# 41.77511429786682
# inside function
# 38.42184400558472
# inside function
# 29.80912470817566
# inside function
# 24.190905570983887
# inside function
# 48.070276498794556
# 20.2966148853302
# 47.35118007659912
# inside function
# 31.34234619140625
# inside function
# 18.148186206817627
# inside function
# 19.627038955688477
# 15.82143759727478
# inside function
# 15.76128625869751
# inside function
# 8.818068027496338
# inside function
# 10.18582797050476
# inside function
# 9.654975652694702
# inside function
# 11.850369215011597
# inside function
# 5.82170295715332
# inside function
# 9.33263874053955
# inside function
# 11.070242881774902
# inside function
# 8.875848770141602
# inside function
# 12.50093960762024
# inside function
# 9.080182313919067
# inside function
# 9.01095986366272
# inside function
# 10.0385160446167
# inside function
# 10.34165906906128
# inside function
# 10.297647953033447
# inside function
# 10.060024976730347
# inside function
# 11.290440559387207
# inside function
# 10.281090497970581
# inside function
# 8.485570192337036
# inside function
# 11.475494146347046
# 7.559216737747192
# 24701.72109389305

# %%
S = librosa.feature.melspectrogram(np.asarray(y), sr=sr, n_mels=128)
log_S = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')

# %%
save_path = pathImage + "neu" + '/' + image_fname + '.jpg'

# %%
from PIL import Image
im=Image.open('/home/user/shaheen.perveen/SER_new/IEMOCAP_image/neutral/Ses05F_impro05_M010.jpg')
im.size
# Out:
# (300, 200)

# %%
plt.imshow(im)
plt.show()

# %%
im_resize = im.resize((256, 256), Image.ANTIALIAS)

# %%
plt.imshow(im_resize)
plt.show()
